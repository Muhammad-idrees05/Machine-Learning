# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data=[np.random.normal(0,std,100)for std in range(1,4)]

# %%
plt.violinplot(data)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x24d47a07af0>,
#   <matplotlib.collections.PolyCollection at 0x24d47a07dc0>,
#   <matplotlib.collections.PolyCollection at 0x24d47a58160>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x24d47a07a90>,
#  'cmins': <matplotlib.collections.LineCollection at 0x24d47a587c0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x24d47a58b80>}

# %%
plt.violinplot(data)
plt.xlabel('Data')
plt.ylabel('Density')
plt.title('Violin Plot')
plt.show()
